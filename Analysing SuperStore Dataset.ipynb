# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
superstore = pd.read_excel('P1-SuperStoreUS-2015.xlsx')

# %%
superstore.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
superstore['cost']=superstore['Profit']-superstore['Sales']

# %%
superstore.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
superstore = pd.read_excel('P1-SuperStoreUS-2015.xlsx',index_col='Order ID')

# %%
superstore.drop('Row ID',axis=1,inplace=True)

# %%
superstore.head()
# Out:
#          Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# Order ID
# 88522              High      0.01        2.84           0.93            3
# 90193     Not Specified      0.02      500.98          26.00            5
# 90192          Critical      0.06        9.48           7.29           11
# 86838            Medium      0.09       78.69          19.99           14
# 86838            Medium      0.08        3.28           2.31           14
#
#               Customer Name       Ship Mode Customer Segment Product Category  \
# Order ID
# 88522         Bonnie Potter     Express Air        Corporate  Office Supplies
# 90193        Ronnie Proctor  Delivery Truck      Home Office        Furniture
# 90192         Marcus Dunlap     Regular Air      Home Office        Furniture
# 86838     Gwendolyn F Tyson     Regular Air   Small Business        Furniture
# 86838     Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies
#
# ...

# %%
superstore.shape
# Out:
# (1952, 23)

# %%
superstore.columns
# Out:
# Index(['Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales'],
#       dtype='object')

# %%
superstore.dtypes
# Out:
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# dtype: object

# %%
superstore['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
superstore.nunique()
# Out:
# Order Priority             6
# Discount                  13
# Unit Price               597
# Shipping Cost            497
# Customer ID             1130
# Customer Name           1130
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name             913
# Product Base Margin       52
# Country                    1
# Region                     4
# State or Province         49
# City                     869
# Postal Code              981
# Order Date               179
# Ship Date                187
# Profit                  1898
# Quantity ordered new      76
# Sales                   1922
# dtype: int64

# %%
superstore.isnull()
# Out:
#           Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# Order ID
# 88522              False     False       False          False        False
# 90193              False     False       False          False        False
# 90192              False     False       False          False        False
# 86838              False     False       False          False        False
# 86838              False     False       False          False        False
# ...                  ...       ...         ...            ...          ...
# 87536              False     False       False          False        False
# 87536              False     False       False          False        False
# 87534              False     False       False          False        False
# 87537              False     False       False          False        False
# 87530              False     False       False          False        False
#
# ...

# %%
superstore.isnull().sum()
# Out:
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# dtype: int64

# %%
superstore['Product Base Margin'].fillna(superstore['Product Base Margin'].mean(),inplace=True)

# %%
superstore.isnull().sum()
# Out:
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# dtype: int64

# %%
#Sales in each Business Segment 

superstore.groupby('Customer Segment').Sales.sum().sort_values()
# Out:
# Customer Segment
# Small Business    400293.94
# Consumer          401778.37
# Home Office       464481.04
# Corporate         657784.53
# Name: Sales, dtype: float64

# %%
#Profit from each Business Segment

superstore.groupby('Customer Segment').Profit.sum().sort_values()
# Out:
# Customer Segment
# Consumer          49894.990273
# Home Office       54433.520871
# Corporate         54444.191002
# Small Business    65304.909691
# Name: Profit, dtype: float64

# %%
#Profit from each Product Category

superstore.groupby('Product Category').Profit.sum().sort_values()
# Out:
# Product Category
# Furniture          59249.445936
# Technology         75303.156364
# Office Supplies    89525.009537
# Name: Profit, dtype: float64

# %%
#Number of Products ordered under each Category

superstore['Product Category'].value_counts()
# Out:
# Office Supplies    1071
# Technology          481
# Furniture           400
# Name: Product Category, dtype: int64

# %%
#Display high priority orders

superstore[superstore['Order Priority']=='High']
# Out:
#          Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# Order ID
# 88522              High      0.01        2.84           0.93            3
# 86836              High      0.04        2.98           1.58           16
# 86836              High      0.05      115.99           2.50           16
# 90031              High      0.05       26.48           6.93           18
# 41793              High      0.05       26.48           6.93           21
# ...                 ...       ...         ...            ...          ...
# 87474              High      0.00        5.98           7.15         3374
# 87474              High      0.09        3.57           4.17         3374
# 87536              High      0.01       10.90           7.46         3397
# 87536              High      0.10        7.99           5.03         3397
# 87530              High      0.10      105.98          13.99         3403
#
# ...

# %%
#Profits in negatives

superstore[superstore['Profit']<=0]
# Out:
#          Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# Order ID
# 90192          Critical      0.06        9.48           7.29           11
# 86838            Medium      0.08        3.28           2.31           14
# 86838            Medium      0.05        3.28           4.20           14
# 86838            Medium      0.05        3.58           1.63           14
# 86837          Critical      0.00        4.42           4.99           15
# ...                 ...       ...         ...            ...          ...
# 87909          Critical      0.08        4.48           2.50         3393
# 87536              High      0.01       10.90           7.46         3397
# 87536              High      0.10        7.99           5.03         3397
# 87534     Not Specified      0.08       11.97           5.81         3399
# 87537            Medium      0.10        9.38           4.93         3400
#
# ...

# %%
plt.figure(figsize=(35,10))
sns.barplot(x='Product Sub-Category',y='Profit',data=superstore)
# Out:
# <AxesSubplot:xlabel='Product Sub-Category', ylabel='Profit'>

# %%
sns.barplot(x='Region', y='Sales', data=superstore)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
sns.countplot(x='Ship Mode',data=superstore)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>
